# %%
import torch
print(f"GPU tersedia: {torch.cuda.is_available()}")
print(f"Nama GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'Tidak ada'}")
# Out:
# GPU tersedia: False
# Nama GPU: Tidak ada
