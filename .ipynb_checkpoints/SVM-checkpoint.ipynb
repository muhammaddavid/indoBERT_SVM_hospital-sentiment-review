# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import product
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from imblearn.under_sampling import RandomUnderSampler

# %%
df = pd.read_csv('data_clean.csv')

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.136949  1.272046  0.510312  0.339855  2.616537 -1.772529  0.410521
# 1  0.914922  1.392725  0.351469 -0.136572  2.503397 -1.849025  0.566180
# 2  0.369162  1.509572  0.297824 -0.049347  2.631128 -2.072258  0.743055
# 3  0.540838  1.792163  0.023101 -0.162051  2.734946 -1.785003  0.614825
# 4  0.783264  1.410416  0.685413 -0.194689  2.816381 -1.509894  0.397465
#
#           7         8         9  ...       759       760       761       762  \
# 0 -0.805142 -0.512995  1.136016  ...  0.091030 -0.492722 -0.300267  0.300478
# 1 -0.816231 -0.669368  0.986369  ...  0.338507 -0.216742  0.108243  0.376062
# 2 -0.543062 -0.564228  1.024444  ...  0.583573 -0.374288  0.201691  0.282205
# 3 -0.643663 -0.272433  1.089182  ...  0.515880 -0.539649  0.167302  0.171435
# 4 -1.076632 -0.103785  1.344515  ...  0.549871 -0.197834  0.130047  0.235434
#
#         763       764       765       766       767  sentiment
# 0  1.742987 -0.800279 -0.657833  0.290007  0.722308          1
# 1  1.769673 -0.556726 -0.440836  0.251842  0.808017          1
# 2  1.716538 -0.473045 -0.346497  0.269129  0.896709          1
# 3  1.963568 -0.260897  0.010230  0.138225  0.756905          1
# 4  1.440770 -0.538142 -0.558781 -0.067099  0.429296          1
#
# [5 rows x 769 columns]

# %%
rus = RandomUnderSampler(random_state=5)

feature_cols = df.columns[:768].tolist()
X_temp = df[feature_cols]
y_temp = df['sentiment']

X_res, y_res = rus.fit_resample(X_temp, y_temp)

df = pd.DataFrame(X_res, columns=feature_cols)
df['sentiment'] = y_res

print("Setelah undersample:", df['sentiment'].value_counts())
# Out:
# Setelah undersample: sentiment
# 0    4876
# 1    4876
# Name: count, dtype: int64

# %%
df.head()
# Out:
#            0         1         2         3         4         5         6  \
# 16  0.437841  1.378125  0.253770 -0.153585  2.604510 -1.547431  0.476560
# 20  1.087023  1.542678  0.857601 -0.267540  2.677015 -1.693577  0.647663
# 21  0.697670  1.285756  0.412275  0.179421  2.495024 -1.954121  0.785095
# 23  1.170252  2.274422  0.872046  0.186353  2.598732 -1.639453  0.198257
# 32  1.022788  2.395046 -0.114039  0.402041  2.419624 -1.434735 -0.332419
#
#            7         8         9  ...       759       760       761       762  \
# 16 -0.645281 -0.801532  1.024680  ...  0.476499 -0.096609 -0.248857  0.088835
# 20 -0.840934 -0.612903  1.099759  ...  0.039993  0.088078  0.131562  0.198266
# 21 -0.980324  0.036652  1.233483  ...  0.391330 -0.310352  0.408615  0.210083
# 23 -1.513268 -0.227135  0.493317  ...  0.376421  0.232404  0.046154  0.270994
# 32 -0.714616 -0.348046  1.430624  ...  0.041821  0.535952  0.009924  0.588959
#
#          763       764       765       766       767  sentiment
# 16  2.167795 -0.396196 -0.345256  0.487496  0.699319          0
# 20  1.819309 -0.320431 -1.001587  0.707353  0.663776          0
# 21  1.724566 -0.134582 -0.202154 -0.024626  0.657762          0
# 23  1.999527 -0.495684 -0.661157 -0.268164  0.414215          0
# 32  2.402876 -0.355139  0.329289 -0.080804  0.309973          0
#
# [5 rows x 769 columns]

# %%
X = df.iloc[:, 0:768]
y = df["sentiment"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=5, stratify=y
)

# %%
print("="*60)
print("  Training Awal — Default Parameter")
print("="*60)

model_default = SVC()
model_default.fit(X_train, y_train)
y_pred_default = model_default.predict(X_test)

acc_default    = accuracy_score(y_test, y_pred_default)
report_default = classification_report(y_test, y_pred_default, output_dict=True)

print(f"Accuracy: {acc_default}")
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred_default))

# Simpan ke JSON
with open("svm_default.json", "w") as f:
    json.dump({
        "accuracy": acc_default,
        "y_true"  : y_test.tolist(),
        "y_pred"  : y_pred_default.tolist(),
        "report"  : report_default
    }, f)

print("Default results saved!")
# Out:
# ============================================================
#   Training Awal — Default Parameter
# ============================================================
# Accuracy: 0.787801127626858
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80       975
#            1       0.81      0.75      0.78       976
#
#     accuracy                           0.79      1951
#    macro avg       0.79      0.79      0.79      1951
# weighted avg       0.79      0.79      0.79      1951
#
# Default results saved!

# %%
param_grid = [
    {'kernel': ['linear'], 'C': [0.1, 1, 10]},
    {'kernel': ['rbf'],  'C': [0.1, 1, 10], 'gamma': ['scale', 0.1, 0.01, 0.001]},
    {'kernel': ['poly'], 'C': [0.1, 1, 10], 'gamma': ['scale', 0.1, 0.01, 0.001]},
]

svm_results  = {}
best_score   = 0
best_params  = {}

# %%
for params in param_grid:
    keys   = [k for k in params if k != 'kernel']
    kernel = params['kernel'][0]

    value_combinations = list(product(*[params[k] for k in keys]))

    for combo in value_combinations:
        current_params = {'kernel': kernel}
        for k, v in zip(keys, combo):
            current_params[k] = v

        print(f"\n{'='*60}")
        print(f"  Parameter: {current_params}")
        print(f"{'='*60}")

        model_svm = SVC(**current_params)
        model_svm.fit(X_train, y_train)
        y_pred = model_svm.predict(X_test)

        acc    = accuracy_score(y_test, y_pred)
        report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)

        print(f"Accuracy: {acc}")
        print("\nClassification Report:\n")
        print(classification_report(y_test, y_pred, zero_division=0))

        # Simpan hasil per kombinasi parameter
        param_key = str(current_params)
        svm_results[param_key] = {
            "accuracy": acc,
            "y_true"  : y_test.tolist(),
            "y_pred"  : y_pred.tolist(),
            "report"  : report
        }

        if acc > best_score:
            best_score  = acc
            best_params = current_params

        # Simpan ke JSON setiap kombinasi selesai
        with open("svm_tuning.json", "w") as f:
            json.dump(svm_results, f)

print(f"\n{'='*60}")
print(f"PARAMETER TERBAIK: {best_params}")
print(f"ACCURACY TERBAIK : {best_score}")
print(f"{'='*60}")

# Simpan best params
with open("svm_best.json", "w") as f:
    json.dump({
        "best_params": best_params,
        "best_score" : best_score
    }, f)

print("Tuning results saved!")
# Out:
# ============================================================
#   Parameter: {'kernel': 'linear', 'C': 0.1}
# ============================================================
# Accuracy: 0.8016401845207586
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81       975
#            1       0.82      0.77      0.80       976
#
#     accuracy                           0.80      1951
#    macro avg       0.80      0.80      0.80      1951
# weighted avg       0.80      0.80      0.80      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'linear', 'C': 1}
# ============================================================
# Accuracy: 0.7903639159405433
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.81      0.79       975
#            1       0.80      0.77      0.79       976
#
#     accuracy                           0.79      1951
#    macro avg       0.79      0.79      0.79      1951
# weighted avg       0.79      0.79      0.79      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'linear', 'C': 10}
# ============================================================
# Accuracy: 0.7852383393131728
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79       975
#            1       0.80      0.77      0.78       976
#
#     accuracy                           0.79      1951
#    macro avg       0.79      0.79      0.79      1951
# weighted avg       0.79      0.79      0.79      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale'}
# ============================================================
# Accuracy: 0.7596104561763198
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.77      0.76       975
#            1       0.77      0.75      0.76       976
#
#     accuracy                           0.76      1951
#    macro avg       0.76      0.76      0.76      1951
# weighted avg       0.76      0.76      0.76      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.1}
# ============================================================
# Accuracy: 0.49974372116863147
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       975
#            1       0.00      0.00      0.00       976
#
#     accuracy                           0.50      1951
#    macro avg       0.25      0.50      0.33      1951
# weighted avg       0.25      0.50      0.33      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.01}
# ============================================================
# Accuracy: 0.7411583803177858
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77       975
#            1       0.81      0.63      0.71       976
#
#     accuracy                           0.74      1951
#    macro avg       0.75      0.74      0.74      1951
# weighted avg       0.75      0.74      0.74      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.001}
# ============================================================
# Accuracy: 0.760635571501794
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76       975
#            1       0.77      0.75      0.76       976
#
#     accuracy                           0.76      1951
#    macro avg       0.76      0.76      0.76      1951
# weighted avg       0.76      0.76      0.76      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'rbf', 'C': 1, 'gamma': 'scale'}
# ============================================================
# Accuracy: 0.787801127626858
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80       975
#            1       0.81      0.75      0.78       976
#
#     accuracy                           0.79      1951
#    macro avg       0.79      0.79      0.79      1951
# weighted avg       0.79      0.79      0.79      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'rbf', 'C': 1, 'gamma': 0.1}
# ============================================================
# Accuracy: 0.6145566376217324
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.94      0.71       975
#            1       0.83      0.29      0.43       976
#
#     accuracy                           0.61      1951
#    macro avg       0.70      0.61      0.57      1951
# weighted avg       0.70      0.61      0.57      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'rbf', 'C': 1, 'gamma': 0.01}
# ============================================================
# Accuracy: 0.7883136852895951
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80       975
#            1       0.81      0.75      0.78       976
#
#     accuracy                           0.79      1951
#    macro avg       0.79      0.79      0.79      1951
# weighted avg       0.79      0.79      0.79      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# ============================================================
# Accuracy: 0.7837006663249616
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79       975
#            1       0.80      0.75      0.78       976
#
#     accuracy                           0.78      1951
#    macro avg       0.79      0.78      0.78      1951
# weighted avg       0.79      0.78      0.78      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'rbf', 'C': 10, 'gamma': 'scale'}
# ============================================================
# Accuracy: 0.805228088159918
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81       975
#            1       0.83      0.76      0.80       976
#
#     accuracy                           0.81      1951
#    macro avg       0.81      0.81      0.80      1951
# weighted avg       0.81      0.81      0.80      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'rbf', 'C': 10, 'gamma': 0.1}
# ============================================================
# Accuracy: 0.628395694515633
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.93      0.71       975
#            1       0.82      0.33      0.47       976
#
#     accuracy                           0.63      1951
#    macro avg       0.70      0.63      0.59      1951
# weighted avg       0.70      0.63      0.59      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'rbf', 'C': 10, 'gamma': 0.01}
# ============================================================
# Accuracy: 0.787288569964121
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79       975
#            1       0.80      0.76      0.78       976
#
#     accuracy                           0.79      1951
#    macro avg       0.79      0.79      0.79      1951
# weighted avg       0.79      0.79      0.79      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# ============================================================
# Accuracy: 0.8103536647872885
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82       975
#            1       0.84      0.76      0.80       976
#
#     accuracy                           0.81      1951
#    macro avg       0.81      0.81      0.81      1951
# weighted avg       0.81      0.81      0.81      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'poly', 'C': 0.1, 'gamma': 'scale'}
# ============================================================
# Accuracy: 0.7626858021527422
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.78      0.77       975
#            1       0.77      0.74      0.76       976
#
#     accuracy                           0.76      1951
#    macro avg       0.76      0.76      0.76      1951
# weighted avg       0.76      0.76      0.76      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'poly', 'C': 0.1, 'gamma': 0.1}
# ============================================================
# Accuracy: 0.7662737057919016
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       975
#            1       0.76      0.78      0.77       976
#
#     accuracy                           0.77      1951
#    macro avg       0.77      0.77      0.77      1951
# weighted avg       0.77      0.77      0.77      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'poly', 'C': 0.1, 'gamma': 0.01}
# ============================================================
# Accuracy: 0.7949769349051768
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.81      0.80       975
#            1       0.81      0.78      0.79       976
#
#     accuracy                           0.79      1951
#    macro avg       0.80      0.79      0.79      1951
# weighted avg       0.80      0.79      0.79      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'poly', 'C': 0.1, 'gamma': 0.001}
# ============================================================
# Accuracy: 0.7585853408508457
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.77      0.76       975
#            1       0.77      0.74      0.76       976
#
#     accuracy                           0.76      1951
#    macro avg       0.76      0.76      0.76      1951
# weighted avg       0.76      0.76      0.76      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'poly', 'C': 1, 'gamma': 'scale'}
# ============================================================
# Accuracy: 0.7939518195797027
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80       975
#            1       0.82      0.75      0.79       976
#
#     accuracy                           0.79      1951
#    macro avg       0.80      0.79      0.79      1951
# weighted avg       0.80      0.79      0.79      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'poly', 'C': 1, 'gamma': 0.1}
# ============================================================
# Accuracy: 0.7662737057919016
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       975
#            1       0.76      0.78      0.77       976
#
#     accuracy                           0.77      1951
#    macro avg       0.77      0.77      0.77      1951
# weighted avg       0.77      0.77      0.77      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'poly', 'C': 1, 'gamma': 0.01}
# ============================================================
# Accuracy: 0.7672988211173757
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       975
#            1       0.76      0.78      0.77       976
#
#     accuracy                           0.77      1951
#    macro avg       0.77      0.77      0.77      1951
# weighted avg       0.77      0.77      0.77      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'poly', 'C': 1, 'gamma': 0.001}
# ============================================================
# Accuracy: 0.7821629933367504
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79       975
#            1       0.80      0.75      0.77       976
#
#     accuracy                           0.78      1951
#    macro avg       0.78      0.78      0.78      1951
# weighted avg       0.78      0.78      0.78      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'poly', 'C': 10, 'gamma': 'scale'}
# ============================================================
# Accuracy: 0.8083034341363403
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.82       975
#            1       0.84      0.77      0.80       976
#
#     accuracy                           0.81      1951
#    macro avg       0.81      0.81      0.81      1951
# weighted avg       0.81      0.81      0.81      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'poly', 'C': 10, 'gamma': 0.1}
# ============================================================
# Accuracy: 0.7662737057919016
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       975
#            1       0.76      0.78      0.77       976
#
#     accuracy                           0.77      1951
#    macro avg       0.77      0.77      0.77      1951
# weighted avg       0.77      0.77      0.77      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'poly', 'C': 10, 'gamma': 0.01}
# ============================================================
# Accuracy: 0.7662737057919016
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       975
#            1       0.76      0.78      0.77       976
#
#     accuracy                           0.77      1951
#    macro avg       0.77      0.77      0.77      1951
# weighted avg       0.77      0.77      0.77      1951
#
#
# ============================================================
#   Parameter: {'kernel': 'poly', 'C': 10, 'gamma': 0.001}
# ============================================================
# Accuracy: 0.805228088159918
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81       975
#            1       0.84      0.76      0.80       976
#
#     accuracy                           0.81      1951
#    macro avg       0.81      0.81      0.80      1951
# weighted avg       0.81      0.81      0.80      1951
#
#
# ============================================================
# PARAMETER TERBAIK: {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# ACCURACY TERBAIK : 0.8103536647872885
# ============================================================
# Tuning results saved!

# %%
rekap = {k: v["accuracy"] for k, v in svm_results.items()}

df_svm = pd.DataFrame.from_dict(rekap, orient='index', columns=['Accuracy'])
df_svm.index.name = 'Parameter'

print("\nREKAP HASIL TUNING SVM")
print("="*60)
print(df_svm.to_string())
print(f"\nDefault Accuracy : {acc_default:.4f}")
print(f"Best Parameter   : {best_params}")
print(f"Best Accuracy    : {best_score:.4f}")
# Out:
# REKAP HASIL TUNING SVM
# ============================================================
#                                                 Accuracy
# Parameter
# {'kernel': 'linear', 'C': 0.1}                  0.801640
# {'kernel': 'linear', 'C': 1}                    0.790364
# {'kernel': 'linear', 'C': 10}                   0.785238
# {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale'}   0.759610
# {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.1}       0.499744
# {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.01}      0.741158
# {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.001}     0.760636
# {'kernel': 'rbf', 'C': 1, 'gamma': 'scale'}     0.787801
# {'kernel': 'rbf', 'C': 1, 'gamma': 0.1}         0.614557
# {'kernel': 'rbf', 'C': 1, 'gamma': 0.01}        0.788314
# {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}       0.783701
# {'kernel': 'rbf', 'C': 10, 'gamma': 'scale'}    0.805228
# {'kernel': 'rbf', 'C': 10, 'gamma': 0.1}        0.628396
# {'kernel': 'rbf', 'C': 10, 'gamma': 0.01}       0.787289
# {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}      0.810354
# {'kernel': 'poly', 'C': 0.1, 'gamma': 'scale'}  0.762686
# {'kernel': 'poly', 'C': 0.1, 'gamma': 0.1}      0.766274
# {'kernel': 'poly', 'C': 0.1, 'gamma': 0.01}     0.794977
# {'kernel': 'poly', 'C': 0.1, 'gamma': 0.001}    0.758585
# {'kernel': 'poly', 'C': 1, 'gamma': 'scale'}    0.793952
# {'kernel': 'poly', 'C': 1, 'gamma': 0.1}        0.766274
# {'kernel': 'poly', 'C': 1, 'gamma': 0.01}       0.767299
# {'kernel': 'poly', 'C': 1, 'gamma': 0.001}      0.782163
# {'kernel': 'poly', 'C': 10, 'gamma': 'scale'}   0.808303
# {'kernel': 'poly', 'C': 10, 'gamma': 0.1}       0.766274
# {'kernel': 'poly', 'C': 10, 'gamma': 0.01}      0.766274
# {'kernel': 'poly', 'C': 10, 'gamma': 0.001}     0.805228
#
# Default Accuracy : 0.7878
# Best Parameter   : {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# Best Accuracy    : 0.8104

# %%
plt.figure(figsize=(14, 6))
colors = ['red' if v == df_svm['Accuracy'].max() else 'steelblue' for v in df_svm['Accuracy']]
plt.bar(df_svm.index, df_svm['Accuracy'], color=colors)
plt.xticks(rotation=90, fontsize=7)
plt.ylabel('Accuracy')
plt.title('Hasil Tuning SVM — Akurasi per Kombinasi Parameter')
plt.tight_layout()
plt.savefig('svm_tuning_results.png', dpi=150)
plt.show()

# %%
best_result = svm_results[str(best_params)]
y_true_best = best_result["y_true"]
y_pred_best = best_result["y_pred"]

cm_best = confusion_matrix(y_true_best, y_pred_best)
plt.figure(figsize=(6, 5))
sns.heatmap(cm_best, annot=True, fmt='d', cmap='Blues',
            xticklabels=['negative', 'positive'],
            yticklabels=['negative', 'positive'])
plt.title(f'Confusion Matrix — SVM Best ({best_params})')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.savefig('svm_confusion_matrix_best.png', dpi=150)
plt.show()
